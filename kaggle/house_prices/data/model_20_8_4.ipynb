# %% [markdown]
# <a href="https://colab.research.google.com/github/tongtiger/KUanwjrrlrP/blob/master/kaggle/house_prices/data/model_20_8_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold

import tensorflow as tf
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("/content/drive/Shared drives/Kaggle/house_prices/data/train_data_20_8_4.csv")
train= pd.DataFrame(train)
train.drop(columns=['Id'], inplace=True)
train
# Out:
#       MSSubClass  MSZoning  LotFrontage  ...  SaleType  SaleCondition  SalePrice
# 0       0.315789         1     0.207668  ...         1              1     208500
# 1       0.105263         1     0.255591  ...         1              1     181500
# 2       0.315789         1     0.217252  ...         1              1     223500
# 3       0.368421         1     0.191693  ...         1              2     140000
# 4       0.315789         1     0.268371  ...         1              1     250000
# ...          ...       ...          ...  ...       ...            ...        ...
# 1455    0.315789         1     0.198083  ...         1              1     175000
# 1456    0.105263         1     0.271565  ...         1              1     210000
# 1457    0.368421         1     0.210863  ...         1              1     266500
# 1458    0.105263         1     0.217252  ...         1              1     142125
# 1459    0.105263         1     0.239617  ...         1              1     147500
#
# ...

# %%
dataset = train.values

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

# %%
X = dataset[:, 0:78+1]
Y = dataset[:, 79]
Y
# Out:
# array([208500., 181500., 223500., ..., 266500., 142125., 147500.])

# %%
n_fold = 10
skf = StratifiedKFold(n_splits = n_fold, shuffle = True, random_state=seed)

# %%
from tqdm import tqdm

for train, test in tqdm(skf.split(X, Y)):
  model = Sequential()
  model.add(Dense(128, input_dim = 79, activation='relu'))
  model.add(Dense(64, activation = 'relu'))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(16, activation='relu'))
  model.add(Dense(8, activation='relu' ))
  model.add(Dense(1))
  model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['accuracy'])
  early_stopping_callback = EarlyStopping(monitor='accuracy', patience = 1000)
  model.fit(X[train], Y[train], epochs = 2000, batch_size=00, verbose=0, callbacks = [early_stopping_callback])
  print(model.predict(X[test], verbose=1), Y[test])
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# 5/5 [==============================] - 0s 2ms/step
# 1it [00:23, 23.72s/it]
# [[205873.   ]
#  [237103.38 ]
#  [283601.88 ]
#  [ 91398.164]
#  [275261.75 ]
#  [196611.92 ]
#  [215642.17 ]
#  [224937.28 ]
#  [118660.6  ]
#  [109366.17 ]
#  [261506.64 ]
#  [127716.73 ]
#  [121250.26 ]
#  [165248.58 ]
#  [ 94726.78 ]
#  [189100.23 ]
#  [ 95833.13 ]
#  [130224.8  ]
#  [219356.48 ]
#  [273311.72 ]
#  [203843.81 ]
#  [481390.88 ]
#  [181683.94 ]
#  [212194.45 ]
#  [333038.34 ]
#  [147650.67 ]
#  [214666.98 ]
#  [115665.32 ]
#  [ 92570.05 ]
#  [114029.13 ]
#  [140150.14 ]
#  [194215.83 ]
#  [298825.66 ]
#  [170846.64 ]
#  [178020.11 ]
#  [207044.62 ]
#  [182350.45 ]
#  [201021.5  ]
#  [162031.52 ]
#  [131845.03 ]
#  [327749.28 ]
#  [175993.47 ]
# ...

# %%
model = Sequential()
model.add(Dense(128, input_dim = 79, activation='relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu' ))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['accuracy'])
early_stopping_callback = EarlyStopping(monitor='accuracy', patience = 750)
model.fit(X, Y, epochs = 2000, batch_size=100, verbose=0, callbacks=[early_stopping_callback])
print(model.evaluate(X, Y)[1])
# Out:
# 46/46 [==============================] - 0s 910us/step - loss: 337122400.0000 - accuracy: 0.0000e+00
# 0.0

# %%
print(model.predict(X, verbose=1), Y)
# Out:
# 46/46 [==============================] - 0s 779us/step
# [[207334.6 ]
#  [192737.98]
#  [212456.67]
#  ...
#  [247973.39]
#  [135827.6 ]
#  [154681.58]] [208500. 181500. 223500. ... 266500. 142125. 147500.]

# %%
model.save("/content/drive/Shared drives/Kaggle/house_prices/model/2020_8_4_patience_750.model")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/Kaggle/house_prices/model/2020_8_4_patience_750.model/assets
